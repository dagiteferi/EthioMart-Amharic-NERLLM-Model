# %%
# import necessarry libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Add the parent directory to the system path
import os 
import sys 
sys.path.append(os.path.abspath(os.path.join('..')))
# importing modules from scripts
import scripts.labeling as l
df = pd.read_csv('../data/cleaned_data.csv')
df
# Out:
#      Unnamed: 0 Channel Title Channel Username    ID  \
# 0             2        ምርጥ ዕቃ        @MerttEka  7439
# 1             3        ምርጥ ዕቃ        @MerttEka  7437
# 2             6        ምርጥ ዕቃ        @MerttEka  7434
# 3             9        ምርጥ ዕቃ        @MerttEka  7431
# 4            12        ምርጥ ዕቃ        @MerttEka  7428
# ..          ...           ...              ...   ...
# 480         914        ምርጥ ዕቃ        @MerttEka  6431
# 481         915        ምርጥ ዕቃ        @MerttEka  6430
# 482         916        ምርጥ ዕቃ        @MerttEka  6429
# 483         917        ምርጥ ዕቃ        @MerttEka  6428
# 484         918        ምርጥ ዕቃ        @MerttEka  6427
#
#                                                Message  \
# 0     \n\n    \n\n ውሃ የማያስገባ የፍራሽ ልብስ\n\n 1.20ሜ ..1...
# 1      /  \n\n ከሴራሚክ የተሰሩ የወጥ እና የገንፎ ሳህኖች\n በጣም ኳሊ...
# 2         \n የልብስ ማስጪያ\nቦታ የማይፈጅ \n የራሱ ጎማ ያለው\n ለአ...
# 3        \n\n  ልብስ መተኮሻ\n2200W ሃይል የሚጠቀም\nልብስ የማያቃጥ...
# 4      \n\n የወይን፣ ኪኒቶ እና መሰል ፈሳሽ መጠጦች ማቅረቢያና መጠጫ\n ...
# ..                                                 ...
# 480    \n\n ተጣጣፊ የላፕቶፕ ማስቀመጪያ\n  ከብረት የተሰራ\n የሚረዝም ...
# 481                    \n\n ይሄንን ./  ተጭነው   ያድርጉ፣ ቤተሰብ
# 482    \n\n የመጥረጊያ መወልወያ እና ብሩሽ ማንጠልጠያ\n ግድግዳ ላይ በቡ...
# 483     \n\nውሃ የማያስገባ\n ብዙ ኪስ ስላለው በርካታ ዕቃ/ልብስ ይይዙበ...
# 484    \n\n የእናቶች ጡት ጫፍ መሸፈኛ \n ለሚያጠቡ እናቶች የሚያስፈልግ\...
#
#                           Date                 Media Path
# 0    2025-01-15 05:13:17+00:00  photos\@MerttEka_7439.jpg
# 1    2025-01-14 14:51:20+00:00  photos\@MerttEka_7437.jpg
# 2    2025-01-14 08:29:45+00:00  photos\@MerttEka_7434.jpg
# 3    2025-01-13 20:46:15+00:00  photos\@MerttEka_7431.jpg
# 4    2025-01-11 13:44:48+00:00  photos\@MerttEka_7428.jpg
# ..                         ...                        ...
# 480  2024-08-16 15:00:18+00:00  photos\@MerttEka_6431.jpg
# 481  2024-08-16 10:56:43+00:00                        NaN
# 482  2024-08-16 10:56:28+00:00  photos\@MerttEka_6429.jpg
# 483  2024-08-16 06:01:13+00:00                        NaN
# 484  2024-08-15 15:40:38+00:00  photos\@MerttEka_6427.jpg
#
# [485 rows x 7 columns]

# %%
df.drop(columns='Unnamed: 0')
# Out:
#     Channel Title Channel Username    ID  \
# 0          ምርጥ ዕቃ        @MerttEka  7439
# 1          ምርጥ ዕቃ        @MerttEka  7437
# 2          ምርጥ ዕቃ        @MerttEka  7434
# 3          ምርጥ ዕቃ        @MerttEka  7431
# 4          ምርጥ ዕቃ        @MerttEka  7428
# ..            ...              ...   ...
# 480        ምርጥ ዕቃ        @MerttEka  6431
# 481        ምርጥ ዕቃ        @MerttEka  6430
# 482        ምርጥ ዕቃ        @MerttEka  6429
# 483        ምርጥ ዕቃ        @MerttEka  6428
# 484        ምርጥ ዕቃ        @MerttEka  6427
#
#                                                Message  \
# 0     \n\n    \n\n ውሃ የማያስገባ የፍራሽ ልብስ\n\n 1.20ሜ ..1...
# 1      /  \n\n ከሴራሚክ የተሰሩ የወጥ እና የገንፎ ሳህኖች\n በጣም ኳሊ...
# 2         \n የልብስ ማስጪያ\nቦታ የማይፈጅ \n የራሱ ጎማ ያለው\n ለአ...
# 3        \n\n  ልብስ መተኮሻ\n2200W ሃይል የሚጠቀም\nልብስ የማያቃጥ...
# 4      \n\n የወይን፣ ኪኒቶ እና መሰል ፈሳሽ መጠጦች ማቅረቢያና መጠጫ\n ...
# ..                                                 ...
# 480    \n\n ተጣጣፊ የላፕቶፕ ማስቀመጪያ\n  ከብረት የተሰራ\n የሚረዝም ...
# 481                    \n\n ይሄንን ./  ተጭነው   ያድርጉ፣ ቤተሰብ
# 482    \n\n የመጥረጊያ መወልወያ እና ብሩሽ ማንጠልጠያ\n ግድግዳ ላይ በቡ...
# 483     \n\nውሃ የማያስገባ\n ብዙ ኪስ ስላለው በርካታ ዕቃ/ልብስ ይይዙበ...
# 484    \n\n የእናቶች ጡት ጫፍ መሸፈኛ \n ለሚያጠቡ እናቶች የሚያስፈልግ\...
#
#                           Date                 Media Path
# 0    2025-01-15 05:13:17+00:00  photos\@MerttEka_7439.jpg
# 1    2025-01-14 14:51:20+00:00  photos\@MerttEka_7437.jpg
# 2    2025-01-14 08:29:45+00:00  photos\@MerttEka_7434.jpg
# 3    2025-01-13 20:46:15+00:00  photos\@MerttEka_7431.jpg
# 4    2025-01-11 13:44:48+00:00  photos\@MerttEka_7428.jpg
# ..                         ...                        ...
# 480  2024-08-16 15:00:18+00:00  photos\@MerttEka_6431.jpg
# 481  2024-08-16 10:56:43+00:00                        NaN
# 482  2024-08-16 10:56:28+00:00  photos\@MerttEka_6429.jpg
# 483  2024-08-16 06:01:13+00:00                        NaN
# 484  2024-08-15 15:40:38+00:00  photos\@MerttEka_6427.jpg
#
# [485 rows x 6 columns]

# %% [markdown]
# # Drop rows with missing values in the Message columns

# %%
df = df.dropna(subset=['Message'])

# %%
message_cleaned = df['Message'].isnull().sum()
print(f"Numer of NAN values in Message columns is {message_cleaned}")
# Out:
# Numer of NAN values in Message columns is 0

# %%
# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(l.label_message_utf8_with_birr)

# Display the updated DataFrame
df.head()
# Out:
#    Unnamed: 0 Channel Title Channel Username    ID  \
# 0           2        ምርጥ ዕቃ        @MerttEka  7439
# 1           3        ምርጥ ዕቃ        @MerttEka  7437
# 2           6        ምርጥ ዕቃ        @MerttEka  7434
# 3           9        ምርጥ ዕቃ        @MerttEka  7431
# 4          12        ምርጥ ዕቃ        @MerttEka  7428
#
#                                              Message  \
# 0   \n\n    \n\n ውሃ የማያስገባ የፍራሽ ልብስ\n\n 1.20ሜ ..1...
# 1    /  \n\n ከሴራሚክ የተሰሩ የወጥ እና የገንፎ ሳህኖች\n በጣም ኳሊ...
# 2       \n የልብስ ማስጪያ\nቦታ የማይፈጅ \n የራሱ ጎማ ያለው\n ለአ...
# 3      \n\n  ልብስ መተኮሻ\n2200W ሃይል የሚጠቀም\nልብስ የማያቃጥ...
# 4    \n\n የወይን፣ ኪኒቶ እና መሰል ፈሳሽ መጠጦች ማቅረቢያና መጠጫ\n ...
#
#                         Date                 Media Path  \
# 0  2025-01-15 05:13:17+00:00  photos\@MerttEka_7439.jpg
# 1  2025-01-14 14:51:20+00:00  photos\@MerttEka_7437.jpg
# 2  2025-01-14 08:29:45+00:00  photos\@MerttEka_7434.jpg
# 3  2025-01-13 20:46:15+00:00  photos\@MerttEka_7431.jpg
# 4  2025-01-11 13:44:48+00:00  photos\@MerttEka_7428.jpg
#
#                                      Labeled_Message
# 0  ውሃ O\nየማያስገባ O\nየፍራሽ O\nልብስ O\n1.20ሜ O\n..1 O\...
# 1  ከሴራሚክ O\nየተሰሩ O\nየወጥ O\nእና I-PRODUCT\nየገንፎ I-P...
# 2  የልብስ I-PRODUCT\nማስጪያ B-PRODUCT\nቦታ O\nየማይፈጅ O\...
# 3  ልብስ O\nመተኮሻ O\n2200W O\nሃይል O\nየሚጠቀም O\nልብስ O\...
# 4  የወይን፣ O\nኪኒቶ O\nእና O\nመሰል O\nፈሳሽ O\nመጠጦች O\nማቅ...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = '../data/labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")
